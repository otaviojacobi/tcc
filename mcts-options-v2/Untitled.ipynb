# %%
from GridWorld import GridWorld
from GridWorldOption import GridWorldOption
from MCTS import MCTS
import time

# %%
with open('easy.txt') as f:
    env_map = f.read()

env = GridWorld(env_map)
first_room_pos = [(i,j) for i in range(6) for j in range(8)]
second_room_pos = [(i,j) for i in range(6) for j in range(9, 15)]
third_room_pos = [(i,j) for i in range(7,13) for j in range(8)]
fourth_room_pos = [(i,j) for i in range(7,13) for j in range(9,15)]

options = [
    # primitives, (0,0) is meaningless
    GridWorldOption((0, 0),   {'all'}, 0, 0),
    GridWorldOption((0, 0),   {'all'}, 1, 1),
    GridWorldOption((0, 0),   {'all'}, 2, 2),
    GridWorldOption((0, 0),   {'all'}, 3, 3),
    #GridWorldOption((9, 12),   {'all'}, 8),

    GridWorldOption((3,8),  set(first_room_pos + second_room_pos + [(6,3)] + [(6,13)]), 4),
    GridWorldOption((6,3),  set(first_room_pos + third_room_pos + [(3,8)] + [(11,8)]), 5),
    GridWorldOption((6,13), set(second_room_pos + fourth_room_pos + [(3,8)] + [(11,8)]), 6),
    GridWorldOption((11,8), set(third_room_pos + fourth_room_pos + [(6,3)] + [(6,13)]), 7),
]

TIME_LIMIT = 100
cputc = 20


env = GridWorld(env_map)
print(env.get_oracle_score())
#while not env.finished():
mcts = MCTS(env, options)
option, _ = mcts.run(TIME_LIMIT, cputc)
# Out:
# -21.0
# id 3
# predicted score -22.0
# value -22.0
# cost -1.0
# id 0
# predicted score -22.0
# value -22.0
# cost -1.0
# id 5
# predicted score -16.0
# value -16.0
# cost -7.0
# id 1
# predicted score -20.0
# value -20.0
# cost -1.0
# id 4
# predicted score -12.0
# value -12.0
# cost -9.0
# id 2
# predicted score -20.0
# value -20.0
# cost -1.0
# id 5
# predicted score -16.0
# value -16.0
# cost -7.0
# id 1
# predicted score -19.0
# value -19.0
# cost -2.0
# id 5
# predicted score -16.0
# value -16.0
# cost -17.0
# id 4
# predicted score -12.0
# value -12.0
# cost -11.0
# id 5
# predicted score -16.0
# value -16.0
# cost -9.0
# id 1
# predicted score -15.0
# value -15.0
# cost -8.0
# id 3
# predicted score -21.0
# value -21.0
# cost -2.0
# id 4
# predicted score -12.0
# value -12.0
# cost -9.0
# id 2
# predicted score -21.0
# value -21.0
# cost -2.0
# id 0
# predicted score -17.0
# value -17.0
# cost -8.0
# id 3
# predicted score -22.0
# value -22.0
# cost -2.0
# id 5
# predicted score -16.0
# value -16.0
# cost -7.0
# id 0
# predicted score -21.0
# value -21.0
# cost -2.0
# id 3
# predicted score -23.0
# value -23.0
# cost -2.0
# id 7
# predicted score -6.0
# value -6.0
# cost -17.0
# id 1
# predicted score -19.0
# value -19.0
# cost -2.0
# id 4
# predicted score -12.0
# value -12.0
# cost -9.0
# id 3
# predicted score -13.0
# value -13.0
# cost -10.0
# id 2
# predicted score -21.0
# value -21.0
# cost -2.0
# id 2
# predicted score -19.0
# value -19.0
# cost -2.0
# id 3
# predicted score -21.0
# value -21.0
# cost -2.0
# id 5
# predicted score -16.0
# value -16.0
# cost -9.0
# id 3
# predicted score -16.0
# value -16.0
# cost -8.0
# id 0
# predicted score -23.0
# value -23.0
# cost -2.0
# id 2
# predicted score -11.0
# value -11.0
# cost -10.0
# id 0
# predicted score -21.0
# value -21.0
# cost -2.0
# id 2
# predicted score -19.0
# value -19.0
# cost -2.0
# id 6
# predicted score -4.0
# value -4.0
# cost -17.0
# id 1
# predicted score -12.0
# value -12.0
# cost -10.0
# id 6
# predicted score -4.0
# value -4.0
# cost -17.0
# id 2
# predicted score -16.0
# value -16.0
# cost -8.0
# id 1
# predicted score -21.0
# value -21.0
# cost -2.0
# id 1
# predicted score -12.0
# value -12.0
# cost -10.0
# id 1
# predicted score -20.0
# value -20.0
# cost -3.0
# id 1
# predicted score -21.0
# value -21.0
# cost -2.0
# id 1
# predicted score -18.0
# value -18.0
# cost -3.0
# id 3
# predicted score -20.0
# value -20.0
# cost -3.0
# id 0
# predicted score -12.0
# value -12.0
# cost -10.0
# id 3
# predicted score -20.0
# value -20.0
# cost -3.0
# id 4
# predicted score -12.0
# value -12.0
# cost -15.0
# id 0
# predicted score -22.0
# value -22.0
# cost -2.0
# id 4
# predicted score -12.0
# value -12.0
# cost -11.0
# id 2
# predicted score -20.0
# value -20.0
# cost -3.0
# id 2
# predicted score -10.0
# value -10.0
# cost -11.0
# id 7
# predicted score -6.0
# value -6.0
# cost -17.0
# id 3
# predicted score -4.0
# value -4.0
# cost -18.0
# id 1
# predicted score -20.0
# value -20.0
# cost -3.0
# id 3
# predicted score -21.0
# value -21.0
# cost -3.0
# id 0
# predicted score -21.0
# value -21.0
# cost -3.0
# id 5
# predicted score -16.0
# value -16.0
# cost -9.0
# id 1
# predicted score -12.0
# value -12.0
# cost -11.0
# id 1
# predicted score -15.0
# value -15.0
# cost -8.0
# id 6
# predicted score 0.0
# value 0.0
# cost -23.0
# id 2
# predicted score -11.0
# value -11.0
# cost -11.0
# id 5
# predicted score -16.0
# value -16.0
# cost -9.0
# id 1
# predicted score -20.0
# value -20.0
# cost -3.0
# id 0
# predicted score -22.0
# value -22.0
# cost -3.0
# id 3
# predicted score -20.0
# value -20.0
# cost -3.0
# id 0
# predicted score -14.0
# value -14.0
# cost -11.0
# id 2
# predicted score -14.0
# value -14.0
# cost -9.0
# id 0
# predicted score -12.0
# value -12.0
# cost -10.0
# id 0
# predicted score -12.0
# value -12.0
# cost -12.0
# id 0
# predicted score -12.0
# value -12.0
# cost -10.0
# id 0
# predicted score -20.0
# value -20.0
# cost -3.0
# id 0
# predicted score -20.0
# value -20.0
# cost -3.0
# id 2
# predicted score -11.0
# value -11.0
# cost -12.0
# id 4
# predicted score -12.0
# value -12.0
# cost -16.0
# id 0
# predicted score -12.0
# value -12.0
# cost -11.0
# id 7
# predicted score -6.0
# value -6.0
# cost -17.0
# id 1
# predicted score -21.0
# value -21.0
# cost -3.0
# id 3
# predicted score -20.0
# value -20.0
# cost -3.0
# id 4
# predicted score -12.0
# value -12.0
# cost -11.0
# id 0
# predicted score -23.0
# value -23.0
# cost -3.0
# id 1
# predicted score -3.0
# value -3.0
# cost -18.0
# id 0
# predicted score -12.0
# value -12.0
# cost -11.0
# id 3
# predicted score -16.0
# value -16.0
# cost -8.0
# id 5
# predicted score -16.0
# value -16.0
# cost -9.0
# id 7
# predicted score -6.0
# value -6.0
# cost -19.0
# id 2
# predicted score -11.0
# value -11.0
# cost -11.0
# id 2
# predicted score -20.0
# value -20.0
# cost -3.0
# id 5
# predicted score -16.0
# value -16.0
# cost -17.0
# id 4
# predicted score -12.0
# value -12.0
# cost -9.0
# id 2
# predicted score -11.0
# value -11.0
# cost -10.0
# id 5
# predicted score -16.0
# value -16.0
# cost -7.0
# id 0
# predicted score -17.0
# value -17.0
# cost -9.0
# id 0
# predicted score -22.0
# value -22.0
# cost -3.0
# id 3
# predicted score -16.0
# value -16.0
# cost -10.0
# id 5
# predicted score -16.0
# value -16.0
# cost -9.0
# id 2
# predicted score -22.0
# value -22.0
# cost -3.0
# id 2
# predicted score -11.0
# value -11.0
# cost -10.0
# id 5
# predicted score -16.0
# value -16.0
# cost -7.0
# id 0
# predicted score -17.0
# value -17.0
# cost -8.0
# id 4
# predicted score -12.0
# value -12.0
# cost -9.0
# id 5
# predicted score -16.0
# value -16.0
# cost -17.0

# %%
mcts.root.info(cputc)
# Out:
# Option ID:  3
# P(s, a):  1.0
# N(s, a):  12
# W(s, a):  -290.0
# Q(s, a):  -24.166666666666668
# C(s, a):  -1.0
# U(s, a):  3.322307280571356
# UCB:  -20.844359386095313
# Option ID:  0
# P(s, a):  1.0
# N(s, a):  13
# W(s, a):  -311.0
# Q(s, a):  -23.923076923076923
# C(s, a):  -1.0
# U(s, a):  3.0849996176734016
# UCB:  -20.838077305403523
# Option ID:  5
# P(s, a):  1.0
# N(s, a):  11
# W(s, a):  -269.0
# Q(s, a):  -24.454545454545453
# C(s, a):  -7.0
# U(s, a):  3.5991662206189687
# UCB:  -20.855379233926485
# Option ID:  1
# P(s, a):  1.0
# N(s, a):  23
# W(s, a):  -531.0
# Q(s, a):  -23.08695652173913
# C(s, a):  -1.0
# U(s, a):  1.7995831103094844
# UCB:  -21.287373411429645
# Option ID:  4
# P(s, a):  1.0
# N(s, a):  17
# W(s, a):  -398.0
# Q(s, a):  -23.41176470588235
# C(s, a):  -9.0
# U(s, a):  2.3994441470793126
# UCB:  -21.01232055880304
# Option ID:  2
# P(s, a):  1.0
# N(s, a):  24
# W(s, a):  -542.0
# Q(s, a):  -22.583333333333332
# C(s, a):  -1.0
# U(s, a):  1.727599785897105
# UCB:  -20.855733547436227

# %%
mcts.root.child_edges[4].get_child().info(cputc)
# Out:
# Option ID:  5
# P(s, a):  1.0
# N(s, a):  1
# W(s, a):  -24.0
# Q(s, a):  -24.0
# C(s, a):  -8.0
# U(s, a):  17.581360736183978
# UCB:  -6.418639263816022
# Option ID:  3
# P(s, a):  1.0
# N(s, a):  3
# W(s, a):  -54.0
# Q(s, a):  -18.0
# C(s, a):  -1.0
# U(s, a):  8.790680368091989
# UCB:  -9.209319631908011
# Option ID:  2
# P(s, a):  1.0
# N(s, a):  3
# W(s, a):  -38.0
# Q(s, a):  -12.666666666666666
# C(s, a):  -1.0
# U(s, a):  8.790680368091989
# UCB:  -3.875986298574677
# Option ID:  6
# P(s, a):  1.0
# N(s, a):  3
# W(s, a):  -37.0
# Q(s, a):  -12.333333333333334
# C(s, a):  -8.0
# U(s, a):  8.790680368091989
# UCB:  -3.542652965241345
# Option ID:  1
# P(s, a):  1.0
# N(s, a):  3
# W(s, a):  -40.0
# Q(s, a):  -13.333333333333334
# C(s, a):  -1.0
# U(s, a):  8.790680368091989
# UCB:  -4.542652965241345
# Option ID:  0
# P(s, a):  1.0
# N(s, a):  3
# W(s, a):  -40.0
# Q(s, a):  -13.333333333333334
# C(s, a):  -1.0
# U(s, a):  8.790680368091989
# UCB:  -4.542652965241345
