# %%
from MCTSLearn import MCTS
from CartPoleOption import CartPoleOption
from CartPole import CartPole
from random import choice
import time

# %%
env = CartPole()


total = 0
while not env.finished():
    #mcts.reset(env)
    print('hi')
    mcts = MCTS(env, options)

    option, _ = mcts.learn(100, 2)
    mcts.info(2)
    #option = choice(options)

    option.executed = False
    while True:
        action = option.get_action(env)

        if action == -1 or env.finished():
            break
        _, r, _ = env.step(action)

        env.env.render()
        time.sleep(0.1)
        total += r
    option.executed = False
    
print(total)
# Out:
# hi
# Option ID:  0
# P(s, a):  1.0
# N(s, a):  44
# W(s, a):  947.5400000000001
# Q(s, a):  21.535
# Q_norm(s, a):  0.24988692899140655
# C(s, a):  1.0
# U(s, a):  0.04779055546596335
# UCB:  0.34546803992333325
# Option ID:  1
# P(s, a):  1.0
# N(s, a):  56
# W(s, a):  1273.9800000000005
# Q(s, a):  22.749642857142867
# Q_norm(s, a):  0.2681990480497944
# C(s, a):  1.0
# U(s, a):  0.037729385894181594
# UCB:  0.3436578198381576
#
#
# hi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31494/1148624720.py in <module>
#       6     #mcts.reset(env)
#       7     print('hi')
# ----> 8     mcts = MCTS(env, options)
#       9
#      10     option, _ = mcts.learn(100, 2)
#
# ~/git/tcc/mcts-options-v2/MCTSLearn.pyx in MCTSLearn.MCTS.__init__()
#      23
#      24     def __init__(self, object env, list options):
# ---> 25         self.root = Node(env.copy(), options)
#      26         self.options = deepcopy(options)
#      27         self.g = {}
#
# ~/git/tcc/mcts-options-v2/CartPole.py in copy(self)
#      24
#      25     def copy(self):
# ---> 26         env_copy = deepcopy(self.env)
#      27         new_pole = CartPole(env_copy)
#      28         new_pole.is_over = self.is_over
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/anaconda3/envs/tcc/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     159                     reductor = getattr(x, "__reduce_ex__", None)
#     160                     if reductor is not None:
# --> 161                         rv = reductor(4)
#     162                     else:
#     163                         reductor = getattr(x, "__reduce__", None)
#
# ValueError: ctypes objects containing pointers cannot be pickled
